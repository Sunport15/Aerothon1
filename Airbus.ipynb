# %% [markdown]
# <a href="https://colab.research.google.com/github/Sunport15/Aerothon1/blob/master/Airbus.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import datetime

# %%
df_fabrication=pd.read_excel('/Washing machine manufacturing company.xlsx',sheet_name='fabrication')

# %%
df_fabrication
# Out:
#                   item item id                              raw material  \
# 0                  tub    T101                               sheet steel
# 1                 pump    T102                                  plastics
# 2             spin tub    T103                           stainless steel
# 3             wash tub    T104        (enameling iron) Porcelain coating
# 4         balance ring    T105                                  plastics
# 5   transmission gears    T107                             cast aluminum
# 6     plastic brackets    T108                                  plastics
# 7                  tub    T109                               sheet steel
# 8                 pump    T110                                  plastics
# 9             spin tub    T111  steel (enameling iron) Porcelain coating
# 10            wash tub    T112        (enameling iron) Porcelain coating
# 11        balance ring    T113                           stainless steel
# ...

# %%
df_fabrication['in date'] = pd.to_datetime(df_fabrication['in date']).dt.date.astype(str)
df_fabrication['out date'] = pd.to_datetime(df_fabrication['out date']).dt.date.astype(str)
# Out:
# <ipython-input-5-1983b3d61b11>:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df_fabrication['in date'] = pd.to_datetime(df_fabrication['in date']).dt.date.astype(str)
# <ipython-input-5-1983b3d61b11>:2: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df_fabrication['out date'] = pd.to_datetime(df_fabrication['out date']).dt.date.astype(str)

# %%
df_fabrication
# Out:
#                   item item id                              raw material  \
# 0                  tub    T101                               sheet steel
# 1                 pump    T102                                  plastics
# 2             spin tub    T103                           stainless steel
# 3             wash tub    T104        (enameling iron) Porcelain coating
# 4         balance ring    T105                                  plastics
# 5   transmission gears    T107                             cast aluminum
# 6     plastic brackets    T108                                  plastics
# 7                  tub    T109                               sheet steel
# 8                 pump    T110                                  plastics
# 9             spin tub    T111  steel (enameling iron) Porcelain coating
# 10            wash tub    T112        (enameling iron) Porcelain coating
# 11        balance ring    T113                           stainless steel
# ...

# %%
df_subassembly=pd.read_excel('/Washing machine manufacturing company.xlsx',sheet_name='sub-assembly')

# %%
df_subassembly
# Out:
#    Assembly ID                process Item ID Machine ID  2020-04-10 00:00:00  \
# 0     SAWM3031  Transmission Assembly    T101   FA_WM124                  NaN
# 1     SAWM3032    Electrical Assembly    T102   FA_WM124                  NaN
# 2     SAWM3033  Transmission Assembly   WM125   FA_WM125                  NaN
# 3     SAWM3034    Electrical Assembly   WM126   FA_WM126                  NaN
# 4     SAWM3035         Tub assemblies   WM127   FA_WM127                  NaN
# 5     SAWM3036    Mechanical assembly   WM128   FA_WM128                  NaN
# 6     SAWM3037        Weld Assembly.    WM129   FA_WM129                  NaN
# 7     SAWM3038     Spot Weld Assembly   WM130   FA_WM130                  NaN
# 8     SAWM3039  Transmission Assembly   WM131   FA_WM131                  NaN
# 9     SAWM3040         Tub assemblies   WM132   FA_WM132                  NaN
# 10    SAWM3041         Weld Assembly.   WM133   FA_WM133                  NaN
# ...

# %%
df_assembly=pd.read_excel('/Washing machine manufacturing company.xlsx',sheet_name='assembly')

# %%
df_assembly
# Out:
#                     process         Process ID           Machine ID  \
# 0     Component Integration  SAWM3036_FA_WM128  MAII1017ECME3020079
# 1        Electrical Testing  SAWM3042_FA_WM134  MAII1017ECME3020080
# 2                Complaince  SAWM3042_FA_WM135  MAII1017ECME3020081
# 3   Certification Standards  SAWM3042_FA_WM136  MAII1017ECME3020082
# 4                pivot dome  SAWM3042_FA_WM137  MAII1017ECME3020083
# 5            brake assembly  SAWM3042_FA_WM138  MAII1017ECME3020084
# 6                    module  SAWM3042_FA_WM139  MAII1017ECME3020085
# 7    Powder Coating Process  SAWM3042_FA_WM140  MAII1017ECME3020086
# 8    Testing and Inspection  SAWM3042_FA_WM141  MAII1017ECME3020087
# 9     Component Integration  SAWM3042_FA_WM142  MAII1017ECME3020088
# 10       Electrical Testing  SAWM3042_FA_WM143  MAII1017ECME3020089
# 11               Complaince  SAWM3042_FA_WM144  MAII1017ECME3020090
# 12  Certification Standards  SAWM3042_FA_WM145  MAII1017ECME3020091
# ...

# %%
duplicates = df_fabrication[df_fabrication.duplicated()]

# %%
print(duplicates)
# Out:
# Empty DataFrame
# Columns: [item, item id, raw material, Quantity, in date, out date]
# Index: []

# %%
duplicates1 = df_subassembly[df_subassembly.duplicated()]
print(duplicates1)
# Out:
# Empty DataFrame
# Columns: [Assembly ID, process, Item ID, Machine ID, 2020-04-10 00:00:00, 2020-06-15 00:00:00, start date, end date, 2020-06-24 00:00:00, 2020-08-17 00:00:00]
# Index: []

# %%
duplicates2 = df_assembly[df_assembly.duplicated()]
print(duplicates2)
# Out:
# Empty DataFrame
# Columns: [process, Process ID, Machine ID, 2020-09-03 00:00:00, 2020-11-30 00:00:00, Start Date , END DATE, 2020-12-02 00:00:00, 2021-02-02 00:00:00]
# Index: []

# %%
# removing time from the start date column of subassembly
date_cols = ['start date']
for col in date_cols:
    df_subassembly[col] = pd.to_datetime(df_subassembly[col]).dt.date
# Out:
# <ipython-input-18-807f634cae09>:4: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df_subassembly[col] = pd.to_datetime(df_subassembly[col]).dt.date

# %%
df_assembly
# Out:
#                     process         Process ID           Machine ID  \
# 0     Component Integration  SAWM3036_FA_WM128  MAII1017ECME3020079
# 1        Electrical Testing  SAWM3042_FA_WM134  MAII1017ECME3020080
# 2                Complaince  SAWM3042_FA_WM135  MAII1017ECME3020081
# 3   Certification Standards  SAWM3042_FA_WM136  MAII1017ECME3020082
# 4                pivot dome  SAWM3042_FA_WM137  MAII1017ECME3020083
# 5            brake assembly  SAWM3042_FA_WM138  MAII1017ECME3020084
# 6                    module  SAWM3042_FA_WM139  MAII1017ECME3020085
# 7    Powder Coating Process  SAWM3042_FA_WM140  MAII1017ECME3020086
# 8    Testing and Inspection  SAWM3042_FA_WM141  MAII1017ECME3020087
# 9     Component Integration  SAWM3042_FA_WM142  MAII1017ECME3020088
# 10       Electrical Testing  SAWM3042_FA_WM143  MAII1017ECME3020089
# 11               Complaince  SAWM3042_FA_WM144  MAII1017ECME3020090
# 12  Certification Standards  SAWM3042_FA_WM145  MAII1017ECME3020091
# ...

# %%
df_assembly
# Out:
#                     process         Process ID           Machine ID  \
# 0     Component Integration  SAWM3036_FA_WM128  MAII1017ECME3020079
# 1        Electrical Testing  SAWM3042_FA_WM134  MAII1017ECME3020080
# 2                Complaince  SAWM3042_FA_WM135  MAII1017ECME3020081
# 3   Certification Standards  SAWM3042_FA_WM136  MAII1017ECME3020082
# 4                pivot dome  SAWM3042_FA_WM137  MAII1017ECME3020083
# 5            brake assembly  SAWM3042_FA_WM138  MAII1017ECME3020084
# 6                    module  SAWM3042_FA_WM139  MAII1017ECME3020085
# 7    Powder Coating Process  SAWM3042_FA_WM140  MAII1017ECME3020086
# 8    Testing and Inspection  SAWM3042_FA_WM141  MAII1017ECME3020087
# 9     Component Integration  SAWM3042_FA_WM142  MAII1017ECME3020088
# 10       Electrical Testing  SAWM3042_FA_WM143  MAII1017ECME3020089
# 11               Complaince  SAWM3042_FA_WM144  MAII1017ECME3020090
# 12  Certification Standards  SAWM3042_FA_WM145  MAII1017ECME3020091
# ...

# %%
df_subassembly
# Out:
#    Assembly ID                process Item ID Machine ID  2020-04-10 00:00:00  \
# 0     SAWM3031  Transmission Assembly    T101   FA_WM124                  NaN
# 1     SAWM3032    Electrical Assembly    T102   FA_WM124                  NaN
# 2     SAWM3033  Transmission Assembly   WM125   FA_WM125                  NaN
# 3     SAWM3034    Electrical Assembly   WM126   FA_WM126                  NaN
# 4     SAWM3035         Tub assemblies   WM127   FA_WM127                  NaN
# 5     SAWM3036    Mechanical assembly   WM128   FA_WM128                  NaN
# 6     SAWM3037        Weld Assembly.    WM129   FA_WM129                  NaN
# 7     SAWM3038     Spot Weld Assembly   WM130   FA_WM130                  NaN
# 8     SAWM3039  Transmission Assembly   WM131   FA_WM131                  NaN
# 9     SAWM3040         Tub assemblies   WM132   FA_WM132                  NaN
# 10    SAWM3041         Weld Assembly.   WM133   FA_WM133                  NaN
# ...

# %%
df_fabrication
# Out:
#                   item item id                              raw material  \
# 0                  tub    T101                               sheet steel
# 1                 pump    T102                                  plastics
# 2             spin tub    T103                           stainless steel
# 3             wash tub    T104        (enameling iron) Porcelain coating
# 4         balance ring    T105                                  plastics
# 5   transmission gears    T107                             cast aluminum
# 6     plastic brackets    T108                                  plastics
# 7                  tub    T109                               sheet steel
# 8                 pump    T110                                  plastics
# 9             spin tub    T111  steel (enameling iron) Porcelain coating
# 10            wash tub    T112        (enameling iron) Porcelain coating
# 11        balance ring    T113                           stainless steel
# ...

# %%
df_fabrication.to_csv(r'Download\Washing_Machine_Normalized.csv', index=False)
